# %%
 import pandas as pd
 df = pd.read_csv("yield.csv")
df
# Out:
#                    MI_County  number  Acres  Yield(Bushels)  Bushels/Acres  \
# 0         Combiend counties        0  19000            88.6       0.004663
# 1                     ANTRIM       1   1600           106.3       0.066437
# 2                     BENZIE       2   1600           126.9       0.079312
# 3                 CHARLEVOIX       3   3200           114.0       0.035625
# 4             GRAND TRAVERSE       4   5800           125.5       0.021638
# 5                   LEELANAU       5   2600           119.6       0.046000
# 6                   MANISTEE       6   2400           118.4       0.049333
# 7                  MISSAUKEE       7  21500           151.6       0.007051
# 8  OTHER (COMBINED) COUNTIES       8   7300           124.5       0.017055
#
#    Unnamed: 5 Unnamed: 6
# 0         NaN        NaN
# 1         NaN        NaN
# 2         NaN
# 3         NaN        NaN
# 4         NaN        NaN
# 5         NaN        NaN
# 6         NaN        NaN
# ...
